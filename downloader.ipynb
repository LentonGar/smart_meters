# %%
import kagglehub
import os
import shutil

# Download the dataset
path = kagglehub.dataset_download("jeanmidev/smart-meters-in-london")

# Create data directory in current directory if it doesn't exist
target_dir = "./data"
os.makedirs(target_dir, exist_ok=True)

# Move or copy the files
print(f"Dataset downloaded to: {path}")
print(f"Moving to: {target_dir}")

# Copy the entire directory
shutil.copytree(path, target_dir, dirs_exist_ok=True)
print(f"Files copied to {target_dir}")
# Out:
# Dataset downloaded to: /home/jack/.cache/kagglehub/datasets/jeanmidev/smart-meters-in-london/versions/21
# Moving to: ./data
# Files copied to ./data
